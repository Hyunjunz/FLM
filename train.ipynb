# %%
from datasets import load_dataset

ds = load_dataset(
    "HAERAE-HUB/KOREAN-WEBTEXT",
    split="train",
    cache_dir="./hf_cache"
)

print(ds[0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:122: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/3.06k [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# ...
# data/train-00000-of-00018.parquet:   0%|          | 0.00/411M [00:00<?, ?B/s]
# data/train-00001-of-00018.parquet:   0%|          | 0.00/419M [00:00<?, ?B/s]
# ...

# %%
# !git clone https://github.com/Hyunjunz/FLM.git
# Out:
# Cloning into 'FLM'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 41 (delta 9), reused 41 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 23.47 KiB | 23.47 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %%bash
#
# cd /content/FLM
#
# python scripts/train_colab_gpu.py \
#     --config configs/colab_medium.json \
#     --tokenizer artifacts/tokenizer_colab_32k \
#     --output-dir artifacts/colab_medium_ckpt \
#     --vocab-size 32000 \
#     --block-size 768 \
#     --batch-size 8 \
#     --grad-accum-steps 4 \
#     --max-steps 100000 \
#     --learning-rate 3e-4 \
#     --amp-dtype fp16 \
#     --tf32 \
#     --shuffle-buffer 16384 \
#     --save-every 5000 \
#     --log-every 20 \
#     --tokenizer-max-docs 200000
