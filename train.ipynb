# %%
from datasets import load_dataset

ds = load_dataset(
    "HAERAE-HUB/KOREAN-WEBTEXT",
    split="train",
    cache_dir="./hf_cache"
)

print(ds[0])

# %%
# !python3 scripts/train_colab_gpu.py --config configs/colab_small.json --vocab-size 16000 --block-size 512 --batch-size 12 --grad-accum-steps 4 --max-steps 50000 --learning-rate 3e-4 --amp-dtype fp16 --tf32 --shuffle-buffer 8192 --save-every 5000
